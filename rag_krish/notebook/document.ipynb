# %% [markdown]
# ### Data Ingestion

# %%
from langchain_core.documents import Document

# %%
doc = Document(
	page_content = 'this is the main text conent I am using to create RAG',
	meta_data={
		"source":"example.txt",
		"pages":1,
		"author":"Me Lol",
		"date_created": "2024-01-01"
	}
)
doc
# Out:
# Document(metadata={}, page_content='this is the main text conent I am using to create RAG')
